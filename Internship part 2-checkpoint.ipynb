# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("DEV_SAMPLE.csv")
df
# Out:
#       Cust_ID  Target  Age Gender    Balance Occupation  No_OF_CR_TXNS  \
# 0      C16505       0   41      M   91519.92   SELF-EMP             38
# 1      C17241       0   52      M  117288.96        SAL             17
# 2      C18802       0   31      F  259827.44       SENP              8
# 3      C19289       0   45      F   26677.55       PROF             14
# 4      C14028       0   39      F   43440.31       SENP              1
# 5      C17960       0   45      M  403324.49       SENP             11
# 6      C10216       1   33      M  245500.00        SAL             24
# 7       C4575       0   26      F  464931.92   SELF-EMP             18
# 8       C6171       0   38      M   49257.03        SAL             19
# 9        C484       1   44      M   10791.71   SELF-EMP             17
# 10     C11969       0   28      M   16180.97        SAL             28
# 11     C18299       0   33      M    4397.95       SENP              8
# ...

# %%
df.shape
# Out:
# (14000, 10)

# %%
df['Holding_Period'].max()
# Out:
# 31

# %%
df['Holding_Period'].min()
# Out:
# 1

# %%
df.describe()
# Out:
#              Target           Age       Balance  No_OF_CR_TXNS           SCR  \
# count  14000.000000  14000.000000  1.400000e+04   14000.000000  14000.000000
# mean       0.088214     38.466643  1.449873e+05      16.795929    556.278500
# std        0.283616      9.537076  1.692614e+05      13.017563    261.464332
# min        0.000000     21.000000  0.000000e+00       0.000000    100.000000
# 25%        0.000000     30.000000  2.372943e+04       7.000000    330.000000
# 50%        0.000000     38.000000  7.905920e+04      14.000000    559.000000
# 75%        0.000000     46.250000  2.132250e+05      22.000000    785.250000
# max        1.000000     55.000000  1.246967e+06      50.000000    999.000000
#
#        Holding_Period
# count    14000.000000
# mean        15.270571
# std          8.967025
# min          1.000000
# 25%          7.000000
# 50%         16.000000
# 75%         23.000000
# max         31.000000

# %%
import seaborn as sns

# %%
sns.distplot(df.Balance)

# %%
active_df = df.loc[df.Balance>144987.25850571482,].copy()                   
active_df.Balance.describe()                                   //mean value of Balance
# Out:
# count    4.906000e+03
# mean     3.270603e+05
# std      1.666938e+05
# min      1.452003e+05
# 25%      2.015314e+05
# 50%      2.560797e+05
# 75%      4.066651e+05
# max      1.246967e+06
# Name: Balance, dtype: float64

# %%
sns.distplot(active_df.Balance)

# %%
df['Balance'].max()
# Out:
# 1246966.77

# %%
df['Balance'].mean()
# Out:
# 144987.25850571482

# %%
active_df['Active'] = np.where(active_df['Balance']>0, 'Yes', 'No')  
active_df.Active.describe()
# Out:
# count     4906
# unique       1
# top        Yes
# freq      4906
# Name: Active, dtype: object

# %%
sns.boxplot(x='Occupation', y='Balance', data = active_df)

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['Age'])
plt.show()

# %%
sns.lmplot(x="Age", 
           y="Balance", 
           hue="Occupation",                 //Seaborn's lmplot is a 2D scatterplot with an optional overlaid regression line.
           ci=None,
           data=active_df);

# %%
sns.lmplot(x="Holding_Period", 
           y="Balance", 
           hue="Target", 
           ci=None,
           data = active_df);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 10 columns):
# Cust_ID           14000 non-null object
# Target            14000 non-null int64
# Age               14000 non-null int64
# Gender            14000 non-null object
# Balance           14000 non-null float64
# Occupation        14000 non-null object
# No_OF_CR_TXNS     14000 non-null int64
# AGE_BKT           14000 non-null object
# SCR               14000 non-null int64
# Holding_Period    14000 non-null int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.1+ MB

# %%
df['Gender'].value_counts()
# Out:
# M    10017
# F     3846
# O      137
# Name: Gender, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 32    543
# 30    531
# 31    520
# 28    511
# 35    499
# 33    482
# 36    476
# 43    471
# 29    469
# 41    469
# 34    461
# 53    459
# 55    450
# 52    417
# 44    417
# 27    412
# 26    409
# 37    406
# 47    395
# 46    392
# 51    391
# 50    384
# 54    383
# 42    383
# 45    381
# 25    374
# 40    371
# 38    357
# 39    342
# 49    325
# 48    296
# 24    268
# 23    253
# 22    154
# 21    149
# Name: Age, dtype: int64

# %%
df['Occupation'].value_counts()
# Out:
# SAL         4101
# PROF        3796
# SENP        3723
# SELF-EMP    2380
# Name: Occupation, dtype: int64

# %%
import seaborn as sns
sns.pairplot(df,hue ='Gender')

# %%
sns.catplot("Occupation","Target",data=df,kind="point")
