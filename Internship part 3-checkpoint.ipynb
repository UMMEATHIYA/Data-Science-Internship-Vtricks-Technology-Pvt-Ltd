# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
df=pd.read_csv("DEV_SAMPLE.csv")
df.head()
# Out:
#   Cust_ID  Target  Age Gender    Balance Occupation  No_OF_CR_TXNS AGE_BKT  \
# 0  C16505       0   41      M   91519.92   SELF-EMP             38   41-45
# 1  C17241       0   52      M  117288.96        SAL             17     >50
# 2  C18802       0   31      F  259827.44       SENP              8   31-35
# 3  C19289       0   45      F   26677.55       PROF             14   41-45
# 4  C14028       0   39      F   43440.31       SENP              1   36-40
#
#    SCR  Holding_Period
# 0  926              15
# 1  768              13
# 2  816               5
# 3  353              18
# 4  751              31

# %%
df.drop("Cust_ID", axis=1,inplace=True)

# %%
df["Gender"] = df["Gender"].astype('category')
df["Gender_Cat"]=df["Gender"].cat.codes
df.drop(["Gender"],axis=1,inplace=True)

# %%
df["Occupation"] = df["Occupation"].astype('category')
df["Occupation_cat"]=df["Occupation"].cat.codes
df.drop(["Occupation"],axis=1,inplace=True)

# %%
df.drop(["AGE_BKT"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Cust_ID  Target  Age Gender    Balance Occupation  No_OF_CR_TXNS AGE_BKT  \
# 0  C16505       0   41      M   91519.92   SELF-EMP             38   41-45
# 1  C17241       0   52      M  117288.96        SAL             17     >50
# 2  C18802       0   31      F  259827.44       SENP              8   31-35
# 3  C19289       0   45      F   26677.55       PROF             14   41-45
# 4  C14028       0   39      F   43440.31       SENP              1   36-40
#
#    SCR  Holding_Period
# 0  926              15
# 1  768              13
# 2  816               5
# 3  353              18
# 4  751              31

# %%
df = pd.read_csv('DEV_SAMPLE.csv', 
                 names=['Target', 'Age', 'Gender', 'Balance', 'Occupation','NO_OF_CR_TXNS','AGE_BKT','SCR','Holding_Period'])

# %%
df["Target"].value_counts()
# Out:
# 0    12765
# 1     1235
# Name: Target, dtype: int64

# %%
corre=df.corr()
import matplotlib.pyplot as plt
plt.figure(figsize=(16,6))
#plt.show()
sns.heatmap(data=corre,annot=True)

# %%
X=df[['Age', 'Balance', 'No_OF_CR_TXNS', 'SCR', 'Holding_Period',
       'Gender_Cat', 'Occupation_cat']]
y=df['Target']
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.4)

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
from sklearn.tree import DecisionTreeClassifier  
classifier = DecisionTreeClassifier()  
classifier.fit(X_train, y_train) 
y_pred=classifier.predict(x_test)

# %%
print('Confusion matrix is as follows')
print(confusion_matrix(y_test,y_pred))
print('Accuracy Metrics')
print(classification_report(y_test,y_pred))
# Out:
# Confusion matrix is as follows
# [[4618  471]
#  [ 463   48]]
# Accuracy Metrics
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      5089
#            1       0.09      0.09      0.09       511
#
#     accuracy                           0.83      5600
#    macro avg       0.50      0.50      0.50      5600
# weighted avg       0.83      0.83      0.83      5600

# %%
from sklearn.metrics import accuracy_score #importing accuracy_score function from sklearn.metrics package
acc = accuracy_score(y_test,y_pred)
print("Accuracy for this model {} %".format(acc*100))
# Out:
# Accuracy for this model 83.32142857142857 %

# %%
#KNN

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier = KNeighborsClassifier()  
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = classifier.predict(X_test)  
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print('Confusion matrix is as follows')
print(confusion_matrix(y_test,y_pred))
print('Accuracy Metrics')
print(classification_report(y_test,y_pred))
# Out:
# Confusion matrix is as follows
# [[5034   55]
#  [ 480   31]]
# Accuracy Metrics
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      5089
#            1       0.36      0.06      0.10       511
#
#     accuracy                           0.90      5600
#    macro avg       0.64      0.52      0.53      5600
# weighted avg       0.86      0.90      0.87      5600

# %%
from sklearn.metrics import accuracy_score #importing accuracy_score function from sklearn.metrics package
acc = accuracy_score(y_test,y_pred)
print("Accuracy for this model {} %".format(acc*100))
# Out:
# Accuracy for this model 90.44642857142857 %

# %%
#Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rclf = RandomForestClassifier(n_estimators=100, max_depth=10,random_state=0)

rclf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=10, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
ry_pred = rclf.predict(X_test)  
print(ry_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test, ry_pred))  
print(classification_report(y_test, ry_pred))
# Out:
# [[5072   17]
#  [ 464   47]]
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.95      5089
#            1       0.73      0.09      0.16       511
#
#     accuracy                           0.91      5600
#    macro avg       0.83      0.54      0.56      5600
# weighted avg       0.90      0.91      0.88      5600

# %%
from sklearn.metrics import accuracy_score #importing accuracy_score function from sklearn.metrics package
acc = accuracy_score(y_test,ry_pred)
print("Accuracy for this model {} %".format(acc*100))
# Out:
# Accuracy for this model 91.41071428571429 %

# %%
Xnew=[[41,16436.10,50,516,1,10]]
Ynew=rclf.predict(Xnew)
Ynew
# Out:
# array([0], dtype=int64)

# %%
import matplotlib.pyplot as plt
res=pd.DataFrame(df['Age'])
res.plot.kde()

# %%
import matplotlib.pyplot as plt
res=pd.DataFrame(df['Balance'])
res.plot.kde()

# %%
import scipy.stats as stats
skewvalue=df['Age'].skew()
print("skew value is",skewvalue)
kur=df['Age'].kurt()
print("kurtosis values is ",kur)
#  kur<3-left skewed
#  kur>3-right skewed
#  kur==3-normal curve#
# Out:
# skew value is 0.09819264061393942
# kurtosis values is  -1.146806869436013

# %%
correlations=df.corr(method='pearson')
print(correlations)
# Out:
#                   Target       Age   Balance  No_OF_CR_TXNS       SCR  \
# Target          1.000000  0.024236 -0.072437       0.131704  0.076211
# Age             0.024236  1.000000 -0.146460       0.055351 -0.003700
# Balance        -0.072437 -0.146460  1.000000      -0.136202 -0.015838
# No_OF_CR_TXNS   0.131704  0.055351 -0.136202       1.000000  0.000952
# SCR             0.076211 -0.003700 -0.015838       0.000952  1.000000
# Holding_Period -0.206368 -0.011275  0.018325      -0.036184 -0.031376
# Gender_Cat      0.032200  0.085502 -0.190802       0.242742 -0.005344
# Occupation_cat  0.015583 -0.060231  0.081550      -0.178055  0.005084
#
#                 Holding_Period  Gender_Cat  Occupation_cat
# Target               -0.206368    0.032200        0.015583
# Age                  -0.011275    0.085502       -0.060231
# Balance               0.018325   -0.190802        0.081550
# No_OF_CR_TXNS        -0.036184    0.242742       -0.178055
# ...

# %%
import seaborn as sns

# %%
sns.catplot("Occupation_cat","Target",data=df,kind="point")

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df.hist() 
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e3ecbe3e8b78> in <module>
# ----> 1 df.hist()
#       2
#       3
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("DEV_SAMPLE.csv")
df
# Out:
#       Cust_ID  Target  Age Gender    Balance Occupation  No_OF_CR_TXNS  \
# 0      C16505       0   41      M   91519.92   SELF-EMP             38
# 1      C17241       0   52      M  117288.96        SAL             17
# 2      C18802       0   31      F  259827.44       SENP              8
# 3      C19289       0   45      F   26677.55       PROF             14
# 4      C14028       0   39      F   43440.31       SENP              1
# 5      C17960       0   45      M  403324.49       SENP             11
# 6      C10216       1   33      M  245500.00        SAL             24
# 7       C4575       0   26      F  464931.92   SELF-EMP             18
# 8       C6171       0   38      M   49257.03        SAL             19
# 9        C484       1   44      M   10791.71   SELF-EMP             17
# 10     C11969       0   28      M   16180.97        SAL             28
# 11     C18299       0   33      M    4397.95       SENP              8
# ...

# %%
df.hist('Target')
plt.show()

# %%
df["Occupation"] = df["Occupation"].astype('category')
df["Occupation_cat"]=df["Occupation"].cat.codes
df.drop(["Occupation"],axis=1,inplace=True)

# %%
df
# Out:
#          Target  Age  Gender    Balance  NO_OF_CR_TXNS  AGE_BKT  SCR  \
# Cust_ID  Target  Age  Gender    Balance  No_OF_CR_TXNS  AGE_BKT  SCR
# C16505        0   41       M   91519.92             38    41-45  926
# C17241        0   52       M  117288.96             17      >50  768
# C18802        0   31       F  259827.44              8    31-35  816
# C19289        0   45       F   26677.55             14    41-45  353
# C14028        0   39       F   43440.31              1    36-40  751
# C17960        0   45       M  403324.49             11    41-45  364
# C10216        1   33       M     245500             24    31-35  166
# C4575         0   26       F  464931.92             18    26-30  448
# C6171         0   38       M   49257.03             19    36-40  237
# C484          1   44       M   10791.71             17    41-45  678
# C11969        0   28       M   16180.97             28    26-30  272
# C18299        0   33       M    4397.95              8    31-35  452
# ...

# %%
df["Gender"] = df["Gender"].astype('category')
df["Gender_Cat"]=df["Gender"].cat.codes
df.drop(["Gender"],axis=1,inplace=True)

# %%
df
# Out:
#          Target  Age    Balance  NO_OF_CR_TXNS  AGE_BKT  SCR  Holding_Period  \
# Cust_ID  Target  Age    Balance  No_OF_CR_TXNS  AGE_BKT  SCR  Holding_Period
# C16505        0   41   91519.92             38    41-45  926              15
# C17241        0   52  117288.96             17      >50  768              13
# C18802        0   31  259827.44              8    31-35  816               5
# C19289        0   45   26677.55             14    41-45  353              18
# C14028        0   39   43440.31              1    36-40  751              31
# C17960        0   45  403324.49             11    41-45  364               2
# C10216        1   33     245500             24    31-35  166               9
# C4575         0   26  464931.92             18    26-30  448              28
# C6171         0   38   49257.03             19    36-40  237               5
# C484          1   44   10791.71             17    41-45  678               3
# ...

# %%
df.drop(["AGE_BKT"],axis=1,inplace=True)

# %%
df
# Out:
#          Target  Age    Balance  NO_OF_CR_TXNS  SCR  Holding_Period  \
# Cust_ID  Target  Age    Balance  No_OF_CR_TXNS  SCR  Holding_Period
# C16505        0   41   91519.92             38  926              15
# C17241        0   52  117288.96             17  768              13
# C18802        0   31  259827.44              8  816               5
# C19289        0   45   26677.55             14  353              18
# C14028        0   39   43440.31              1  751              31
# C17960        0   45  403324.49             11  364               2
# C10216        1   33     245500             24  166               9
# C4575         0   26  464931.92             18  448              28
# C6171         0   38   49257.03             19  237               5
# C484          1   44   10791.71             17  678               3
# C11969        0   28   16180.97             28  272               7
# C18299        0   33    4397.95              8  452              19
# ...

# %%
from sklearn.utils import resample

# %%
df_majority = df[df.Target==0]
df_minority = df[df.Target==1]

# %%
df['Target'].value_counts()
# Out:
# 0         12765
# 1          1235
# Target        1
# Name: Target, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import numpy as np
import pandas as pd

df_train = pd.read_csv('DEV_SAMPLE.csv')

Target_count = df_train.Target.value_counts()
print('Class 0:', Target_count[0])
print('Class 1:', Target_count[1])
print('Proportion:', round(Target_count[0] / Target_count[1], 2), ': 1')

Target_count.plot(kind='bar', title='Count (Target)');
# Out:
# Class 0: 12765
# Class 1: 1235
# Proportion: 10.34 : 1

# %%
X = df[df.Target==0]
y = df[df.Target==1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e2c4ddd4e583> in <module>
# ----> 1 X = df[df.Target==0]
#       2 y = df[df.Target==1]
#
# NameError: name 'df' is not defined

# %%
df['Target'].value_counts()
# Out:
# 0         12765
# 1          1235
# Target        1
# Name: Target, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
import numpy as np
import pandas as pd
df=pd.read_csv("DEV_SAMPLE.csv")

# %%
X=df[['Age', 'Balance', 'No_OF_CR_TXNS', 'SCR', 'Holding_Period',
       'Gender_Cat', 'Occupation_cat']]
y=df['Target']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-48197019d6f5> in <module>
# ----> 1 X=df[['Age', 'Balance', 'No_OF_CR_TXNS', 'SCR', 'Holding_Period',
#       2        'Gender_Cat', 'Occupation_cat']]
#       3 y=df['Target']
#
# NameError: name 'df' is not defined

# %%
X_resampled,y_resampled = SMOTE().fit_sample(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b2301a3aa41b> in <module>
# ----> 1 X_resampled,y_resampled = SMOTE().fit_sample(X,y)
#
# NameError: name 'X' is not defined
